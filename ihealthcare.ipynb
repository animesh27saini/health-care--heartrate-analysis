# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as st
# %matplotlib inline

# %%
data = pd.read_csv(r'E:\nit\17th - Test, Seaborn, Eda Practicle\EDA- HEALTHCARE DOMAIN\heart.csv')
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data.shape
# Out:
# (303, 14)

# %%
data.size
# Out:
# 4242

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
#  ###### legend

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data['sex'].describe
# Out:
# <bound method NDFrame.describe of 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 298    0
# 299    1
# 300    1
# 301    1
# 302    0
# Name: sex, Length: 303, dtype: int64>

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].nunique()
# Out:
# 2

# %%
data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x = 'target', data = data) 
plt.show()

# %%
data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
p, bx = plt.subplots(figsize=(8,6))
bx = sns.countplot(x='sex', hue = 'target', data=data)
plt.show()

# %%
p, bx = plt.subplots(figsize=(8,6))
bx = sns.countplot(y='target', hue = 'sex', data=data)
plt.show()

# %%
bx = sns.catplot(x='target',col='sex',data=data,kind='count',height = 8,aspect = 1)

# %%
r, cx = plt.subplots(figsize=(4,6))
ax = sns.countplot(data=data, x='target',palette ='Set1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\3705338448.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=data, x='target',palette ='Set1')

# %%
r, cx = plt.subplots(figsize=(8,6))
cx = sns.countplot(x='target',data=data,facecolor = (0,0,0,0),linewidth = 5,edgecolor = sns.color_palette('dark' , 4))

# %%
s, dx = plt.subplots(figsize=(4,8))
dx = sns.countplot(x = 'target', hue = 'fbs' ,data = data)
plt.show()

# %%
s, dx = plt.subplots(figsize=(4,8))
dx = sns.countplot(x = 'target', hue = 'exang' ,data = data)
plt.show()

# %% [markdown]
# ## Bivariate analysis

# %%
correlation = data.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
data['cp'].nunique()
# Out:
# 4

# %%
data['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(6,8))
ax = sns.countplot(x='cp',data=data)
plt.show()

# %%
data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='cp', hue = 'target',data=data)
plt.show()

# %%
## alternatively we can show that in another way

ax = sns.catplot(x= 'target',col ='cp',data=data, height = 3,aspect  = 1 , kind='count')

# %%
data['thalach'].nunique()
# Out:
# 91

# %%
data['thalach'].value_counts()
# Out:
# thalach
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
#        ..
# 202     1
# 184     1
# 121     1
# 192     1
# 90      1
# Name: count, Length: 91, dtype: int64

# %%
c ,qx = plt.subplots(figsize=(6,8))
x = data['thalach']
qx = sns.distplot(x,bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\537608325.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   qx = sns.distplot(x,bins=10)

# %%
c ,qx = plt.subplots(figsize=(6,8))
x = data['thalach']
x = pd.Series(x,name='Thalach Variable')
qx = sns.distplot(x,bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\1894552109.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   qx = sns.distplot(x,bins=10)

# %%
f, ax = plt.subplots(figsize=(8,10))
x = data['thalach']
ax = sns.distplot(x,bins=10 , vertical= True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\4285711565.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x,bins=10 , vertical= True)

# %%
f, ax = plt.subplots(figsize=(8,10))
x = data['thalach']
x = pd.Series(x , name = 'Thalach Variable' )
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,10))
sns.set_style('darkgrid') 
x = data['thalach']
x = pd.Series(x , name = 'Thelach Variable' )
ax = sns.distplot(x , kde= False,rug = True, bins = 10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\3686991045.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x , kde= False,rug = True, bins = 10)

# %%
f, ax = plt.subplots(figsize=(8,10))
sns.stripplot(x= "target" , y="thalach", data=data)
plt.show()

# %%
f , ax = plt.subplots(figsize=(8,6))
sns.stripplot(x = 'target' , y = 'thalach' , data= data , jitter = 0.01)
plt.show()

# %%
f , ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = 'target' , y = 'thalach' , data = data)
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation , square = True , annot=True , fmt ='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels())
a.set_yticklabels(a.set_yticklabels())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 5
#       3 a = sns.heatmap(correlation , square = True , annot=True , fmt ='.2f', linecolor='white')
#       4 a.set_xticklabels(a.get_xticklabels())
# ----> 5 a.set_yticklabels(a.set_yticklabels())
#       6 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
# ...

# %%
new = ['age' ,'trestbps','chol','thalach','oldpeak','target']
sns.pairplot(data[new] , kind ='scatter' , diag_kind='hist')
plt.show()

# %%
data['age'].nunique()
# Out:
# 41

# %%
data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f , ax = plt.subplots(figsize=(10,6))
x = data['age']
ax = sns.distplot(x , bins =10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8820\740920598.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x , bins =10)

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.stripplot(x= "target" , y="age", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x= "target" , y="age", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x= "age" , y="trestbps", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.regplot(x= "age" , y="trestbps", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x= "age" , y="chol", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.regplot(x= "age" , y="chol", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x= "chol" , y="thalach", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.regplot(x= "chol" , y="thalach", data=data)
plt.show()

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(data).all().all()

# %%
assert (data >= 0).all().all()

# %%
data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f ,ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = data['age'])
plt.show()

# %%
data['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f , ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = data['trestbps'])
plt.show()

# %%
data['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f , aax = plt.subplots(figsize=(8,6))
sns.boxplot(x = data['chol'])
plt.show()

# %%
data['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x = data['thalach'])
plt.show()

# %%
data['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x= data['oldpeak'])
plt.show()
